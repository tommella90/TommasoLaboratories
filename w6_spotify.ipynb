# %% [markdown]
# # SPOTIFY

# %%
import config
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
# serach song
results = sp.search(q="Like a Rolling Stone",limit=1,market="GB")

# %%
dict1 = {'tracks': 4, 'key2': 5, 'key3': 4}
dict1
list = [1,3,4,7]
list
# Out:
# [1, 3, 4, 7]

# %%
rolling_stones_500 = sp.user_playlist_tracks("spotify", "6uRb2P6XRj5ygnanxpMCfS")
rolling_stones_500['items'][0]['track']['name']
# Out:
# 'Like a Rolling Stone'

# %%
track = sp.search(q="Like a Rolling Stone")
track
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Like+a+Rolling+Stone&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74ASZWbe4lXaubB36ztrGX'},
#        'href': 'https://api.spotify.com/v1/artists/74ASZWbe4lXaubB36ztrGX',
#        'id': '74ASZWbe4lXaubB36ztrGX',
#        'name': 'Bob Dylan',
#        'type': 'artist',
#        'uri': 'spotify:artist:74ASZWbe4lXaubB36ztrGX'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
# ...

# %%
sp.audio_features(track['tracks']['items'][0]['id'])
# Out:
# [{'danceability': 0.482,
#   'energy': 0.721,
#   'key': 0,
#   'loudness': -6.839,
#   'mode': 1,
#   'speechiness': 0.0321,
#   'acousticness': 0.731,
#   'instrumentalness': 0,
#   'liveness': 0.189,
#   'valence': 0.557,
#   'tempo': 95.263,
#   'type': 'audio_features',
#   'id': '3AhXZa8sUQht0UEdBJgpGc',
#   'uri': 'spotify:track:3AhXZa8sUQht0UEdBJgpGc',
#   'track_href': 'https://api.spotify.com/v1/tracks/3AhXZa8sUQht0UEdBJgpGc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3AhXZa8sUQht0UEdBJgpGc',
#   'duration_ms': 369600,
#   'time_signature': 4}]

# %%
song_list = []
#playlist = sp.user_playlist_tracks("spotify", "6uRb2P6XRj5ygnanxpMCfS")
playlist = sp.user_playlist_tracks("spotify", "59pRUY7wdHjzAyetJtqCnY")

for i in range(0,100):
    song = playlist['items'][i]['track']['name']
    song_list.append(song)
    track = sp.search(q=song)
    sp.audio_features(track["tracks"]["items"][0]["id"] )
    print(song, sp.audio_features(track['tracks']['items'][0]['id']))
print(len(song_list))
# Out:
# Power [{'danceability': 0.542, 'energy': 0.914, 'key': 0, 'loudness': -4.747, 'mode': 0, 'speechiness': 0.113, 'acousticness': 0.0161, 'instrumentalness': 0, 'liveness': 0.744, 'valence': 0.576, 'tempo': 153.993, 'type': 'audio_features', 'id': '2gZUPNdnz5Y45eiGxpHGSc', 'uri': 'spotify:track:2gZUPNdnz5Y45eiGxpHGSc', 'track_href': 'https://api.spotify.com/v1/tracks/2gZUPNdnz5Y45eiGxpHGSc', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2gZUPNdnz5Y45eiGxpHGSc', 'duration_ms': 292093, 'time_signature': 4}]
# ...

# %%
song_list
# Out:
# ['Power',
#  'Give It Up',
#  'Ferrari',
#  'Heaven Takes You Home (feat. Connie Constance)',
#  'Move Your Body',
#  'Sun Goes Down (Sound Of Violence)',
#  'Always',
#  'Be Someone',
#  'Down Under (feat. Colin Hay) (Majestic Remix)',
#  'Highs And Lows',
#  'Hippies (feat. Two Another)',
#  'Stay The Night',
#  '2MUCH (feat. Kyra Mastro)',
#  'Descobridor dos Sete Mares: Remix',
#  'Do It To It',
#  'You Give Me A Feeling',
#  'Nah (feat. Sinead Harnett)',
#  'Closer (Cool Keedz Remix)',
#  'Shout It Back',
#  "Groovejet (If This Ain't Love) [feat. Sophie Ellis-Bextor]",
#  'Bad Habits',
#  'Cold Heart - PNAU Remix',
#  "Don't Be Shy",
#  'U&Me',
#  'Stupid Feelings',
#  'NINGUÉM ME ENSINOU (feat. Lagum) - KVSH REMIX',
#  'Never Going Home',
#  'You for Me',
#  'Ghost',
#  'Closure',
#  'Summer Thing',
#  'Turning Me Up (Hadal Ahbek)',
#  'Going Dumb',
#  'BED',
#  'Make Me Feel',
#  'Rasputin',
#  'Vida Louca (Bruno Be & Breaking Beattz Remix)',
#  'Think - Original Mix',
# ...

# %%
song = rolling_stones_500['items'][i]['track']['name']
song
# Out:
# "(I Can't Get No) Satisfaction - Mono Version / Remastered 2002"

# %%
track = sp.search(q="3AhXZa8sUQht0UEdBJgpGc")
track
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=3AhXZa8sUQht0UEdBJgpGc&type=track&offset=0&limit=10',
#   'items': [],
#   'limit': 10,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 0}}

# %%
#sp.audio_features(track)
sp.audio_features(sp.search(q="3AhXZa8sUQht0UEdBJgpGc"))
# Out:
# [None]

# %%
|
