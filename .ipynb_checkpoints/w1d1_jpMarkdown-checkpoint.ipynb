# %% [markdown]
# # Day 1 Lab

# %% [markdown]
# ## Laboratory on markdown

# %%
input("Person's  name ")
# Out:
# Person's  name Tommaso
# 'Tommaso'

# %%
from IPython.display import Image
Image("C:/Users/tomma/Pictures/me.jpg")

# %%
input("My next holiday will be in ")
# Out:
# My next holiday will be in Celle
# 'Celle'

# %%
input("Is it sea, mountains or other? " )
# Out:
# Is it sea, mountains or other? Sea
# 'Sea'

# %%
Image("C:/Users/tomma/Pictures/99512-Celle-Ligure.jpg")

# %%
input("Name 3 things you are going to do ")
# Out:
# Name 3 things you are going to do Sleeping swimming sleeping
# 'Sleeping swimming sleeping'

# %% [markdown]
# **This is where Il spend my holidays**
